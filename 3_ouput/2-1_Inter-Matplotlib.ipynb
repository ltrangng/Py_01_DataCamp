# %% [markdown]
# # Matplotlib
#
# -    [Matplotlib](#Matplotlib)
# -    [Line plot](#Line-plot)
# -    [Scatter plot](#Scatter-plot)
# -    [Histogram](#Histogram)
# -    [Customization](#Customization)

# %% [markdown]
# Data visualization is an important part of data analysis. It is used firstly to explore your data set. The better you understand your data, the better you'll be able to extract insights. And then you will need data visualization to share your insights with other people.
#
# <img src="attachment:1bbcb51b-ec45-4d12-a1ad-333138e0f7cb.png" width="500">
#
# Example of data visualization: The Gapminder plot, made my Hans Rosling, the swedish educator. By making beautiful plots, he allows the data to tell their own story.
#
# <img src="attachment:aec6b0bd-366b-4a49-8f5d-277d3e81dc54.png" width="800">

# %% [markdown]
# ### **Matplotlib**
#
# There are many data visualization packages in Python, but the mother of all is **matplotlib**. You will need the subpackage `pyplot`. By convention it is imported as `plt`.

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# For example, let's try to gain some insights in the evolution of the world population.

# %%
year = [1950, 1970, 1990, 2010]
pop = [2.519, 3.692, 5.263, 6.972] # expressed in billions.

# %% [markdown]
# To plot this data as a line chart, we call `plt.plot()` and use our two lists as arguments. The first argument corresponds to the horizontal axis, the second to the vertical.

# %%
plt.plot(year, pop) 
plt.show()

# %% [markdown]
# The plot does not pop up right away. You will have to call the `plot.show()` function first. This is because you might want to add some more extra elements to your plot before actually displaying it, such as title and label customizations.
#
# The `plt.plot()` function tells Python what to plot and how to plot it. `plt.show()` actually displays the plot.
#
# There are four data points, and Python draws a line between them.
#
# <img src="attachment:d16a6d58-cf56-465a-bb3c-70612730dcf1.png" width="400">
#
# Another type of plot is the scatter plot. The resulting plot simply plots all the individual data points.

# %%
plt.scatter(year, pop)
plt.show()

# %% [markdown]
# ### **Line plot**
#
# Line plots are the most basic plot in Matplotlib. General syntax is like this:
#
# `import matplotlib.pyplot as plt
# plt.plot(x, y)
# plt.show()`
#
# Examine line plots for larger data sets. The world bank has estimates of the world population for the years 1950 up to 2100.

# %%
from numpy import genfromtxt
year = genfromtxt("https://raw.githubusercontent.com/ltrangng/Py_01_DataCamp/main/0_data/year.csv", dtype = "int", delimiter = ",")
pop = genfromtxt("https://raw.githubusercontent.com/ltrangng/Py_01_DataCamp/main/0_data/pop.csv", dtype = "float", delimiter = ",")

# %% [markdown]
# Print the last item from `year` and `pop` to see the predicted population in 2100.

# %%
print(year[-1])
print(pop[-1])
# Out:
# 2100
# 10.85

# %% [markdown]
# Make a line plot: `year` on the x-axis, `pop` on the y-axis

# %%
plt.plot(year, pop)
plt.show()

# %% [markdown]
# The plot looks more smooth now because there are more data points. We can see around 2060 the world population will reach 10 billion.
#
# Now start working on the data that professor Hans Rosling used to build his beautiful bubble chart. It was collected in 2007. `life_exp` contains the life expectancy for each country and `gdp_cap`, which contains the GDP per capita for each country expressed in US Dollars.
# GDP stands for Gross Domestic Product. It basically represents the size of the economy of a country. Divide this by the population and you get the GDP per capita.

# %%
life_exp = genfromtxt("https://raw.githubusercontent.com/ltrangng/Py_01_DataCamp/main/0_data/life_exp.csv", dtype = "float", delimiter = ",")
gdp_cap = genfromtxt("https://raw.githubusercontent.com/ltrangng/Py_01_DataCamp/main/0_data/gdp_cap.csv", dtype = "float", delimiter = ",")

# %% [markdown]
# Print the last item from both the list `gdp_cap`, and the list `life_exp`; it is information about Zimbabwe.

# %%
print(life_exp[-1])
print(gdp_cap[-1])
# Out:
# 43.487
# 469.70929810000007

# %% [markdown]
# Build a line chart, with `gdp_cap` on the x-axis, and `life_exp` on the y-axis.

# %%
plt.plot(gdp_cap, life_exp)
plt.show()

# %% [markdown]
# The line plot does not make much sense. When you have a time scale along the horizontal axis, the line plot is your friend. But in many other cases, when you're trying to assess if there's a correlation between two variables, for example, the scatter plot is the better choice.

# %% [markdown]
# ### **Scatter plot**
#
# Syntax for building a scatter plot:
#
# `import matplotlib.pyplot as plt
# plt.scatter(x, y)
# plt.show()`
#
# Change the line plot for `gdp_cap` versus `life_exp` to scatter plot:

# %%
plt.scatter(gdp_cap, life_exp)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-3771b43c0363> in <module>
# ----> 1 plt.scatter(gdp_cap, life_exp)
#       2 plt.show()
#
# NameError: name 'plt' is not defined

# %% [markdown]
# A correlation will become clear when you display the GDP per capita on a logarithmic scale.

# %%
plt.scatter(gdp_cap, life_exp)
plt.xscale("log")
plt.show()

# %% [markdown]
# The plot shows that the higher GDP usually corresponds to a higher life expectancy. In other words, there is a positive correlation. How about  a relationship between population and life expectancy of a country?

# %%
pop_2007 = genfromtxt("https://raw.githubusercontent.com/ltrangng/Py_01_DataCamp/main/0_data/pop_2007.csv", dtype = "float", delimiter = ",")

# %%
plt.scatter(pop_2007,life_exp)
plt.show()

# %% [markdown]
# The plot shows no clear relationship between population and life expectancy, which makes perfect sense.

# %% [markdown]
# ### **Histogram**
#
# Histogram is a type of visualization that is very useful to explore your data. It shows the distribution of the variables.
# Too se how histogram works, imagine we have 12 values between 0 and 6. To build a histogram for these values, divide the number line into equal chunks called *bins*. Next you count how many data points sit inside each bin. Finally, you draw a bar for each bin. The result is a histogram which shows an overview on how the 12 values are distributed: most values are in the middle, and there are more values below 2 than above 4.
#
#
# <img src="attachment:80118d23-dd2e-495a-9664-81624e644ad7.png" width="450">
#
# `hist()` function in matplotlib is used to build a histogram.
#
# `plt.hist(x, bins =...)`
#
#
# Ask Help for more information:

# %%
help(plt.hist)
# Out:
# Help on function hist in module matplotlib.pyplot:
#
# hist(x, bins=None, range=None, density=False, weights=None, cumulative=False, bottom=None, histtype='bar', align='mid', orientation='vertical', rwidth=None, log=False, color=None, label=None, stacked=False, *, data=None, **kwargs)
#     Plot a histogram.
#
#     Compute and draw the histogram of *x*.  The return value is a tuple
#     (*n*, *bins*, *patches*) or ([*n0*, *n1*, ...], *bins*, [*patches0*,
#     *patches1*, ...]) if the input contains multiple data.  See the
#     documentation of the *weights* parameter to draw a histogram of
#     already-binned data.
#
#     Multiple data can be provided via *x* as a list of datasets
#     of potentially different length ([*x0*, *x1*, ...]), or as
#     a 2-D ndarray in which each column is a dataset.  Note that
#     the ndarray form is transposed relative to the list form.
#
#     Masked arrays are not supported.
#
# ...

# %% [markdown]
# There are a lot of arguments you can specify, but the most import are `x`, which is the list of values you want to build data for, and `bins` to tell Python how many bins the data should be divided. Based on this number,  `hist` will automatically find appropriate boundaries for all bins, and calculate how many values are in each one. By default `bins = 10`.
#
# Generate a histogram with the list of 12 values:

# %%
values = [0,0.6,1.4,1.6,2.2,2.5,2.6,3.2,3.5,3.9,4.2,6]
plt.hist(values, bins = 3)
plt.show()

# %% [markdown]
# Histograms are really useful to give a bigger picture. As an example, the population pyramid is one form of horizontal bin histogram. The ages distribution is shown, both males and females, in EU. The bins are largest for the ages from 40 to 44 in 2010. But the figures will change in 2050 as the baby boomer will get older. Histogram makes it easy to see how demographics changes over the time.
#
# ![grafik.png](attachment:9a7cb8d2-35ec-4e6d-a819-3e821a2ae6e1.png)
#
# Create a histogram for `life_exp` to see how life expectancy in different countries is distributed:

# %%
plt.hist(life_exp)
plt.show()

# %% [markdown]
# When you do not specify the number of bins, by default, Python sets the number of bins to 10 in that case. The number of bins is pretty important. Too few bins will oversimplify reality and won't show you the details. Too many bins will overcomplicate reality and won't show the bigger picture.
#
# Experiment with different numbers of bins. Use `plt.show()` and `plt.clf()` to display and clean up the plot.

# %%
plt.hist(life_exp, bins = 5)
plt.show()
plt.clf()

# %%
plt.hist(life_exp, bins = 20)
plt.show()
plt.clf()

# %% [markdown]
# The histogram makes it easy to compare, for example, life expectancy in 2007 and in 1950.

# %%
life_exp_1950 = genfromtxt("https://raw.githubusercontent.com/ltrangng/Py_01_DataCamp/main/0_data/life_exp_1950.csv", dtype = "float", delimiter = ",")

# %% [markdown]
# Build two histograms to see the difference.

# %%
plt.hist(life_exp, bins = 15)
plt.show()
plt.clf()

# %%
plt.hist(life_exp_1950, bins = 15)
plt.show()
plt.clf()

# %% [markdown]
# ### **Customization**
#
# Creating a plot is one thing, making the correct plot, that makes the message very clear, is the real challenge. There are different types of plot, and for each plot you can do infinite number of customization like color, shape, label, axis and so on. The choice depends on the data and the story you want to tell with this data.
#
# Run again the line plot for population projections till 2100, this time improve it by adding labels to the x and y axes.

# %%
plt.plot(year, pop)
plt.xlabel("Year")
plt.ylabel("Population")
plt.show()

# %% [markdown]
# Add title:

# %%
plt.plot(year, pop)
plt.xlabel("Year")
plt.ylabel("Population")
plt.title("World Population Projections")
plt.show()

# %% [markdown]
# To put the population growth in perspective, we could have the y-axis started from 0. `plt.yticks()` function does that with the syntax: `plt.yticks([0,1,2], ["one","two","three"])`. The input is a list from 0 to 10 with an interval of 2. The second argument names the ticks (here B stands for billions).

# %%
plt.plot(year, pop)
plt.xlabel("Year")
plt.ylabel("Population")
plt.title("World Population Projections")
plt.yticks([0, 2, 4, 6, 8, 10], ["0", "2B", "4B", "6B", "8B", "10B"])
plt.show()

# %% [markdown]
# Add some more historical data to accentuate the population explosion in the last 60 years:

# %%
year = year = [1800, 1850, 1900] + year
pop = [1.0, 1.262, 1.650] + pop

# %% [markdown]
# Run the code for histogram again to complete the picture.

# %%
plt.plot(year, pop)
plt.xlabel("Year")
plt.ylabel("Population")
plt.title("World Population Projections")
plt.yticks([0, 2, 4, 6, 8, 10], ["0", "2B", "4B", "6B", "8B", "10B"])
plt.show()

# %% [markdown]
# Customize the scatter plot of life expectancy vs. GDP per capita.

# %%
plt.scatter(gdp_cap, life_exp)
plt.xscale("log")
plt.xlabel('GDP per Capita [in USD]')
plt.ylabel('Life Expectancy [in years]')
plt.title('World Development in 2007')
plt.show()

# %% [markdown]
# Use `xticks()` function to replace the number on the x-axis with the customized ticks.

# %%
plt.scatter(gdp_cap, life_exp)
plt.xscale("log")
plt.xlabel('GDP per Capita [in USD]')
plt.ylabel('Life Expectancy [in years]')
plt.title('World Development in 2007')
plt.xticks([1000, 10000, 100000], ['1k', '10k', '100k'])
plt.show()

# %% [markdown]
# Right now, the scatter plot is just a cloud of blue dots, indistinguishable from each other. Change the size of the dots so that they corresponds to the population.

# %%
plt.scatter(gdp_cap, life_exp, s = pop_2007)
plt.xscale("log")
plt.show()

# %% [markdown]
# Looks good, but increasing the size of the bubbles will make things stand out more.

# %%
import numpy as np
np_pop = np.array(pop_2007) 
plt.scatter(gdp_cap, life_exp, s = np_pop * 2)
plt.xscale("log")
plt.show()

# %% [markdown]
# The next step is making the plot more colorful! To do this, create a list of color for each corresponding country, depending on the continent the country is part of.

# %%
dict = {
    'Asia':'red',
    'Europe':'green',
    'Africa':'blue',
    'Americas':'yellow',
    'Oceania':'black'
}
col = ['red', 'green', 'blue', 'blue', 'yellow', 'black', 'green', 'red', 'red', 'green', 'blue', 'yellow', 'green', 'blue', 'yellow', 'green', 'blue', 'blue', 'red', 'blue', 'yellow', 'blue', 'blue', 'yellow', 'red', 'yellow', 'blue', 'blue', 'blue', 'yellow', 'blue', 'green', 'yellow', 'green', 'green', 'blue', 'yellow', 'yellow', 'blue', 'yellow', 'blue', 'blue', 'blue', 'green', 'green', 'blue', 'blue', 'green', 'blue', 'green', 'yellow', 'blue', 'blue', 'yellow', 'yellow', 'red', 'green', 'green', 'red', 'red', 'red', 'red', 'green', 'red', 'green', 'yellow', 'red', 'red', 'blue', 'red', 'red', 'red', 'red', 'blue', 'blue', 'blue', 'blue', 'blue', 'red', 'blue', 'blue', 'blue', 'yellow', 'red', 'green', 'blue', 'blue', 'red', 'blue', 'red', 'green', 'black', 'yellow', 'blue', 'blue', 'green', 'red', 'red', 'yellow', 'yellow', 'yellow', 'red', 'green', 'green', 'yellow', 'blue', 'green', 'blue', 'blue', 'red', 'blue', 'green', 'blue', 'red', 'green', 'green', 'blue', 'blue', 'green', 'red', 'blue', 'blue', 'green', 'green', 'red', 'red', 'blue', 'red', 'blue', 'yellow', 'blue', 'green', 'blue', 'green', 'yellow', 'yellow', 'yellow', 'red', 'red', 'red', 'blue', 'blue']

# %% [markdown]
# Add `c = col` to the arguments of the `plt.scatter()` function.

# %%
plt.scatter(gdp_cap, life_exp, s = np_pop * 2, c = col )
plt.xscale("log")
plt.show()

# %% [markdown]
# Change the opacity of the bubbles by setting the `alpha` argument to 0.6, so that the plot is more readable. Alpha can be set from zero to one, where zero is totally transparent, and one is not at all transparent.

# %%
plt.scatter(gdp_cap, life_exp, s = np_pop * 2, c = col, alpha = 0.6 )
plt.xscale("log")
plt.show()

# %% [markdown]
# Additional customizations like `plt.grid(True)` turns the gridlines on, and `plt.text()` adds text on the plot.

# %%
plt.scatter(gdp_cap, life_exp, s = np_pop * 2, c = col, alpha = 0.6 )
plt.xscale("log")
plt.grid(True)
plt.text(1550, 71, 'India')
plt.text(5700, 80, 'China')
plt.show()

# %% [markdown]
# Final plot looks almost like Hans Rosling's. From the plot we can interpret that people live longer in countries with a higher GDP per capita. No high income countries have really short life expectancy, and no low income countries have very long life expectancy. Still, there is a huge difference in life expectancy between countries on the same income level. Most people live in middle income countries where difference in lifespan is huge between countries; depending on how income is distributed and how it is used.

# %%
plt.scatter(gdp_cap, life_exp, s = np_pop * 2, c = col, alpha = 0.6 )
plt.xscale("log")
plt.xlabel('GDP per Capita [in USD]')
plt.ylabel('Life Expectancy [in years]')
plt.title('World Development in 2007')
plt.xticks([1000, 10000, 100000], ['1k', '10k', '100k'])
plt.grid(True)
plt.text(1550, 71, 'India')
plt.text(5700, 80, 'China')
plt.show()
